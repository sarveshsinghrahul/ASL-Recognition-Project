# %%
import tensorflow as tf

# Assume 'my_model.keras' is your saved Keras model
# Load the model first
model = tf.keras.models.load_model('asl_landmark_model.keras')

# Define the path where you want to save the SavedModel
export_path = 'tfmodel'

# Export the model as a SavedModel
model.export(export_path)

print(f"Model exported to SavedModel format at: {export_path}")
# Out:
# INFO:tensorflow:Assets written to: tfmodel/assets
# INFO:tensorflow:Assets written to: tfmodel/assets
# Saved artifact at 'tfmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 63), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 29), dtype=tf.float32, name=None)
# Captures:
#   132332238719632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238724560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238729312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238756976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238763136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238763840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238763488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132332238801024: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
